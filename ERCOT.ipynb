# %% [markdown]
# <h2 id="tocheading">Table of Contents</h2>
# <div id="toc"></div>

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %%
from spreadsheetfunctions import *
# Out:
# Using TensorFlow backend.

# %%
from openpyxl import load_workbook
wb = load_workbook(filename = 'ERCOTNorth.xlsx')

# %%
wb.sheetnames
# Out:
# ['Jan',
#  'Feb',
#  'Mar',
#  'Apr',
#  'May',
#  'Jun',
#  'Jul',
#  'Aug',
#  'Sep',
#  'Oct',
#  'Nov',
#  'Dec']

# %%
ercot = pd.read_excel('ERCOTNorth.xlsx' , sheet_name= None , parse_dates=[['Delivery Date', 'Hour Ending']] )

# %%
ercotdate = pd.read_excel('ERCOTNorth.xlsx' , sheet_name= None  )

# %%
help(pd.DataFrame())
# Out:
# Help on DataFrame in module pandas.core.frame object:
#
# class DataFrame(pandas.core.generic.NDFrame)
#  |  Two-dimensional size-mutable, potentially heterogeneous tabular data
#  |  structure with labeled axes (rows and columns). Arithmetic operations
#  |  align on both row and column labels. Can be thought of as a dict-like
#  |  container for Series objects. The primary pandas data structure.
#  |
#  |  Parameters
#  |  ----------
#  |  data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, or list-like objects
#  |
#  |      .. versionchanged :: 0.23.0
#  |         If data is a dict, argument order is maintained for Python 3.6
#  |         and later.
#  |
#  |  index : Index or array-like
#  |      Index to use for resulting frame. Will default to RangeIndex if
#  |      no indexing information part of input data and no index provided
#  |  columns : Index or array-like
# ...

# %%
ercot
# Out:
# OrderedDict([('Jan',
#                     Delivery Date_Hour Ending Repeated Hour Flag Settlement Point  \
#               0              01/01/2019 01:00                  N        HB_BUSAVG
#               1              01/01/2019 01:00                  N       HB_HOUSTON
#               2              01/01/2019 01:00                  N        HB_HUBAVG
#               3              01/01/2019 01:00                  N         HB_NORTH
#               4              01/01/2019 01:00                  N         HB_SOUTH
#               5              01/01/2019 01:00                  N          HB_WEST
#               6              01/01/2019 01:00                  N           LZ_AEN
#               7              01/01/2019 01:00                  N           LZ_CPS
#               8              01/01/2019 01:00                  N       LZ_HOUSTON
#               9              01/01/2019 01:00                  N          LZ_LCRA
# ...

# %%
def makeadataframewithmutiplesheet(xml):
    full_table = pd.DataFrame()
    for name, sheet in xml.items():
        sheet['sheet'] = name
        sheet = sheet.rename(columns=lambda x: x.split('\n')[-1])
        full_table = full_table.append(sheet)

        full_table.reset_index(inplace=True, drop=True)
    return full_table

# %%
fulldf_ercot = makeadataframewithmutiplesheet(ercot)

# %%
fulldf_ercot
# Out:
#       Delivery Date Delivery Date_Hour Ending Hour Ending Repeated Hour Flag  \
# 0               NaN          01/01/2019 01:00         NaN                  N
# 1               NaN          01/01/2019 01:00         NaN                  N
# 2               NaN          01/01/2019 01:00         NaN                  N
# 3               NaN          01/01/2019 01:00         NaN                  N
# 4               NaN          01/01/2019 01:00         NaN                  N
# 5               NaN          01/01/2019 01:00         NaN                  N
# 6               NaN          01/01/2019 01:00         NaN                  N
# 7               NaN          01/01/2019 01:00         NaN                  N
# 8               NaN          01/01/2019 01:00         NaN                  N
# 9               NaN          01/01/2019 01:00         NaN                  N
# 10              NaN          01/01/2019 01:00         NaN                  N
# ...

# %%
fulldf_ercot= fulldf_ercot[['Delivery Date_Hour Ending','Settlement Point', 'Settlement Point Price']]

# %%
fulldf_ercot.set_index('Delivery Date_Hour Ending', inplace= True)

# %%
fulldf_ercot.head()
# Out:
#                           Settlement Point  Settlement Point Price
# Delivery Date_Hour Ending
# 01/01/2019 01:00                 HB_BUSAVG                   20.49
# 01/01/2019 01:00                HB_HOUSTON                   20.12
# 01/01/2019 01:00                 HB_HUBAVG                   20.54
# 01/01/2019 01:00                  HB_NORTH                   20.49
# 01/01/2019 01:00                  HB_SOUTH                   20.34

# %%
import qgrid

# %%
for qgrid_functions in dir(qgrid):
    print(qgrid_functions)
# Out:
# QGridWidget
# QgridWidget
# __all__
# __builtins__
# __cached__
# __doc__
# __file__
# __loader__
# __name__
# __package__
# __path__
# __spec__
# __version__
# _jupyter_nbextension_paths
# _version
# disable
# enable
# grid
# off
# on
# set_defaults
# set_grid_option
# show_grid
# version_info

# %%
full_qgrid = qgrid.show_grid(fulldf_ercot)

# %%
full_qgrid
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %% [markdown]
# ## get_changed_df() qgrid function gives you a df copy of the grid you create

# %%
onlynorth= full_qgrid.get_changed_df()

# %% [markdown]
# >> Saving North Data to a pickle

# %% [markdown]
# onlynorth.to_pickle('onlynorthdataafterqgrid.pkl')

# %% [markdown]
# >> Reading data from Pickle

# %%
onlynorth= pd.read_pickle('onlynorthdataafterqgrid.pkl')

# %%
type(onlynorth)
# Out:
# pandas.core.frame.DataFrame

# %%
onlynorth.columns
# Out:
# Index(['Settlement Point', 'Settlement Point Price'], dtype='object')

# %%
import time
import datetime

# %%
import numpy as np

# %%
onlynorth.reset_index(inplace=True)

# %%
onlynorth.head()
# Out:
#   Delivery Date_Hour Ending Settlement Point  Settlement Point Price
# 0          01/01/2019 01:00         HB_NORTH                   20.49
# 1          01/01/2019 02:00         HB_NORTH                   19.81
# 2          01/01/2019 03:00         HB_NORTH                   19.58
# 3          01/01/2019 04:00         HB_NORTH                   19.23
# 4          01/01/2019 05:00         HB_NORTH                   21.23

# %%
onlynorth['deltahour']= np.nan

# %%
onlynorth.head(30)
# Out:
#    Delivery Date_Hour Ending Settlement Point  Settlement Point Price  \
# 0           01/01/2019 01:00         HB_NORTH                   20.49
# 1           01/01/2019 02:00         HB_NORTH                   19.81
# 2           01/01/2019 03:00         HB_NORTH                   19.58
# 3           01/01/2019 04:00         HB_NORTH                   19.23
# 4           01/01/2019 05:00         HB_NORTH                   21.23
# 5           01/01/2019 06:00         HB_NORTH                   22.58
# 6           01/01/2019 07:00         HB_NORTH                   23.97
# 7           01/01/2019 08:00         HB_NORTH                   24.55
# 8           01/01/2019 09:00         HB_NORTH                   24.91
# 9           01/01/2019 10:00         HB_NORTH                   24.69
# 10          01/01/2019 11:00         HB_NORTH                   24.62
# 11          01/01/2019 12:00         HB_NORTH                   25.34
# ...

# %%
onlynorth['deltahour']=  onlynorth['Delivery Date_Hour Ending'].apply(lambda x: int(x[11:13]))

# %%
onlynorth['Date'] = onlynorth['Delivery Date_Hour Ending'].apply(lambda x: x[:10])

# %%
onlynorth['Date']= pd.to_datetime(onlynorth['Date'])

# %%
#import timedelta in spreadsheetfunction.py
onlynorth['deltahour']= pd.to_timedelta(onlynorth['deltahour'], unit= 'h')

# %%
onlynorth.head()
# Out:
#   Delivery Date_Hour Ending Settlement Point  Settlement Point Price  \
# 0          01/01/2019 01:00         HB_NORTH                   20.49
# 1          01/01/2019 02:00         HB_NORTH                   19.81
# 2          01/01/2019 03:00         HB_NORTH                   19.58
# 3          01/01/2019 04:00         HB_NORTH                   19.23
# 4          01/01/2019 05:00         HB_NORTH                   21.23
#
#   deltahour       Date
# 0  01:00:00 2019-01-01
# 1  02:00:00 2019-01-01
# 2  03:00:00 2019-01-01
# 3  04:00:00 2019-01-01
# 4  05:00:00 2019-01-01

# %%
 onlynorth["Formatted_DATE"]= onlynorth['Date']+ onlynorth['deltahour']

# %%
onlynorth.head(30)
# Out:
#    Delivery Date_Hour Ending Settlement Point  Settlement Point Price  \
# 0           01/01/2019 01:00         HB_NORTH                   20.49
# 1           01/01/2019 02:00         HB_NORTH                   19.81
# 2           01/01/2019 03:00         HB_NORTH                   19.58
# 3           01/01/2019 04:00         HB_NORTH                   19.23
# 4           01/01/2019 05:00         HB_NORTH                   21.23
# 5           01/01/2019 06:00         HB_NORTH                   22.58
# 6           01/01/2019 07:00         HB_NORTH                   23.97
# 7           01/01/2019 08:00         HB_NORTH                   24.55
# 8           01/01/2019 09:00         HB_NORTH                   24.91
# 9           01/01/2019 10:00         HB_NORTH                   24.69
# 10          01/01/2019 11:00         HB_NORTH                   24.62
# 11          01/01/2019 12:00         HB_NORTH                   25.34
# ...

# %%
onlynorthformatted= onlynorth[['Formatted_DATE', 'Settlement Point Price']]

# %%
onlynorthformatted.set_index(['Formatted_DATE'], inplace= True)

# %%
onlynorthformatted.head()
# Out:
#                      Settlement Point Price
# Formatted_DATE
# 2019-01-01 01:00:00                   20.49
# 2019-01-01 02:00:00                   19.81
# 2019-01-01 03:00:00                   19.58
# 2019-01-01 04:00:00                   19.23
# 2019-01-01 05:00:00                   21.23

# %%
onlynorthformatted.plot();

# %%
df= onlynorthformatted.reset_index()

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %%
df.columns
# Out:
# Index(['Formatted_DATE', 'Settlement Point Price'], dtype='object')

# %%
data = [go.Scatter(x=.Formatted_DATE, y=df['Settlement Point Price'])]

py.iplot(data, filename = 'time-series-simple')

# %%
data = [go.Scatter(x=df.Formatted_DATE, y=df['Settlement Point Price'])]

py.iplot(data, filename = 'time-series-simple')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~MarcSchneider71/6.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# onlynorthformatted.to_pickle("onlynorthformatted.pkl")

# %%
onlynorthformatted= pd.read_pickle("onlynorthformatted.pkl")

# %%
X= onlynorthformatted['Settlement Point Price'].values

# %% [markdown]
# ## ELECTRICITY PRICES ARE STATIONARY

# %%
adfuller(X)
# Out:
# (-6.759790433496871,
#  2.811222443174376e-09,
#  26,
#  2780,
#  {'1%': -3.4327044418732235,
#   '5%': -2.862580225972113,
#   '10%': -2.567323744759588},
#  21980.705573409003)

# %% [markdown]
# # FBProphet Model

# %%
Model= proph(weekly_seasonality= False, daily_seasonality= True, yearly_seasonality= False)

# %%
ERCOTprophet = onlynorthformatted.reset_index()

# %%
ERCOTprophet.head()
# Out:
#        Formatted_DATE  Settlement Point Price
# 0 2019-01-01 01:00:00                   20.49
# 1 2019-01-01 02:00:00                   19.81
# 2 2019-01-01 03:00:00                   19.58
# 3 2019-01-01 04:00:00                   19.23
# 4 2019-01-01 05:00:00                   21.23

# %%
ERCOTprophet = ERCOTprophet.rename(columns={'Formatted_DATE': 'ds',
                        'Settlement Point Price' : 'y' })

# %%
ERCOTprophet.dropna(inplace=True)

# %%
Model.fit(ERCOTprophet)

# %%
ERCOT_dates = Model.make_future_dataframe(periods=48, freq='H', include_history= False)

# %%
ERCOT_dates.tail()
# Out:
#                     ds
# 43 2019-04-29 20:00:00
# 44 2019-04-29 21:00:00
# 45 2019-04-29 22:00:00
# 46 2019-04-29 23:00:00
# 47 2019-04-30 00:00:00

# %%
ERCOT_forecast = Model.predict(ERCOT_dates)

# %%
ERCOT_forecast
# Out:
#                     ds      trend  yhat_lower  yhat_upper  trend_lower  \
# 0  2019-04-28 01:00:00  21.719309   -6.194052   38.487108    21.719309
# 1  2019-04-28 02:00:00  21.716180   -9.046293   37.754854    21.716180
# 2  2019-04-28 03:00:00  21.713050  -10.868121   34.592235    21.713050
# 3  2019-04-28 04:00:00  21.709920  -11.844178   35.599580    21.709920
# 4  2019-04-28 05:00:00  21.706790   -8.263375   39.509101    21.706790
# 5  2019-04-28 06:00:00  21.703661   -1.184526   44.392383    21.703661
# 6  2019-04-28 07:00:00  21.700531    5.078849   49.197035    21.700531
# 7  2019-04-28 08:00:00  21.697401    6.599338   53.741957    21.697401
# 8  2019-04-28 09:00:00  21.694271    3.767209   50.536059    21.694271
# 9  2019-04-28 10:00:00  21.691141    2.263567   48.113087    21.691141
# 10 2019-04-28 11:00:00  21.688012   -1.060354   45.384567    21.688012
# 11 2019-04-28 12:00:00  21.684882   -2.597305   42.624604    21.684882
# ...

# %%
#fig, ax = plt.subplots()
Model.plot(ERCOT_forecast, uncertainty= True,
    xlabel= "Time",
    ylabel= "ERCOT NORTH SETTLEMENT PRICE")
plt.show();

# %%
ERCOT_forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(30)
# Out:
#                     ds       yhat  yhat_lower  yhat_upper
# 18 2019-04-28 19:00:00  29.585139    8.127542   52.968657
# 19 2019-04-28 20:00:00  28.377991    4.466896   51.379145
# 20 2019-04-28 21:00:00  24.596526    1.211090   47.313970
# 21 2019-04-28 22:00:00  20.445650   -1.977909   43.664479
# 22 2019-04-28 23:00:00  17.838071   -4.662520   41.461999
# 23 2019-04-29 00:00:00  16.813448   -7.462808   41.042588
# 24 2019-04-29 01:00:00  15.898545   -5.780354   41.174132
# 25 2019-04-29 02:00:00  14.025814   -7.818924   37.190393
# 26 2019-04-29 03:00:00  12.036203  -11.506867   35.304520
# 27 2019-04-29 04:00:00  12.156701   -9.860332   35.766375
# 28 2019-04-29 05:00:00  15.843221   -8.193406   38.009658
# 29 2019-04-29 06:00:00  22.052940   -0.435427   44.033120
# 30 2019-04-29 07:00:00  27.687743    3.120213   50.961272
# 31 2019-04-29 08:00:00  29.914982    7.576410   53.769551
# 32 2019-04-29 09:00:00  28.292768    5.065951   51.218734
# ...

# %%
Model.plot_components(ERCOT_forecast, uncertainty= True)
plt.show()

# %% [markdown]
# # RNN

# %%
ercotfutureval = ERCOT_forecast[['ds', 'yhat']]

# %%
ercotfutureval.columns= ['Formatted_DATE','Settlement Point Price'
 ]

# %%
ercotfutureval.set_index(['Formatted_DATE'], inplace= True)

# %%
ercotfutureval.head(20)
# Out:
#                      Settlement Point Price
# Formatted_DATE
# 2019-04-28 01:00:00               15.973660
# 2019-04-28 02:00:00               14.100928
# 2019-04-28 03:00:00               12.111318
# 2019-04-28 04:00:00               12.231816
# 2019-04-28 05:00:00               15.918336
# 2019-04-28 06:00:00               22.128054
# 2019-04-28 07:00:00               27.762857
# 2019-04-28 08:00:00               29.990097
# 2019-04-28 09:00:00               28.367882
# 2019-04-28 10:00:00               24.901259
# 2019-04-28 11:00:00               22.118573
# 2019-04-28 12:00:00               21.060715
# 2019-04-28 13:00:00               20.993526
# 2019-04-28 14:00:00               20.844399
# 2019-04-28 15:00:00               20.674554
# 2019-04-28 16:00:00               21.597667
# 2019-04-28 17:00:00               24.278140
# 2019-04-28 18:00:00               27.689000
# 2019-04-28 19:00:00               29.585139
# 2019-04-28 20:00:00               28.377991

# %%
onlynorthformatted.tail()
# Out:
#                      Settlement Point Price
# Formatted_DATE
# 2019-04-27 20:00:00                   25.58
# 2019-04-27 21:00:00                   26.49
# 2019-04-27 22:00:00                   24.43
# 2019-04-27 23:00:00                   22.08
# 2019-04-28 00:00:00                   21.32

# %%
joineddf= pd.concat([onlynorthformatted, ercotfutureval])

# %% [markdown]
# ## joineddf.to_pickle('joineddf.pkl')
# Saving new dataframe as a pickle

# %%
from spreadsheetfunctions import *
# Out:
# Using TensorFlow backend.

# %%
joineddf = pd.read_pickle('joineddf.pkl')

# %%
onlynorthformatted= pd.read_pickle("onlynorthformatted.pkl")

# %%
joineddf.tail()
# Out:
#                      Settlement Point Price
# Formatted_DATE
# 2019-04-29 20:00:00               28.302876
# 2019-04-29 21:00:00               24.521411
# 2019-04-29 22:00:00               20.370535
# 2019-04-29 23:00:00               17.762957
# 2019-04-30 00:00:00               16.738333

# %% [markdown]
# joineddf.to_csv('joineddf.csv')

# %%
dataset = joineddf.values
split= int(.9*len(onlynorthformatted))
train = dataset[0:split,:]
valid = dataset[split:,:]

# %%
len(train)
# Out:
# 2526

# %%
#converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# %%
# Create a data structure with 60 timesteps and 1 output
x_train, y_train = [], []
for i in range(60,len(train)):
    x_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

#Reshaping (batch_size, timesteps, input_dim)
x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# %%
#predicting values, using past 60 from the train data
inputs = joineddf[len(joineddf) - len(valid) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)

# %%
x_train.shape, y_train.shape
# Out:
# ((2466, 60, 1), (2466,))

# %%
x_train.shape[1]
# Out:
# 60

# %%
X_test.shape
# Out:
# (329, 60)

# %%
model = Sequential()
model.add(LSTM(units=200, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(Dropout(.2))
model.add(LSTM(units=200))
model.add(Dropout(.2))
model.add(Dense(1)) #1 output (prediction of next day)

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=100, batch_size=None, verbose=2) #passing None as batch size defaults to minibatch
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
#  - 44s - loss: 9.1723e-04
# Epoch 2/100
#  - 39s - loss: 8.0957e-04
# Epoch 3/100
#  - 49s - loss: 7.1649e-04
# Epoch 4/100
#  - 126s - loss: 6.6025e-04
# Epoch 5/100
#  - 63s - loss: 5.9957e-04
# Epoch 6/100
#  - 41s - loss: 5.7277e-04
# Epoch 7/100
#  - 40s - loss: 5.0803e-04
# Epoch 8/100
#  - 40s - loss: 5.1340e-04
# Epoch 9/100
#  - 40s - loss: 4.5960e-04
# Epoch 10/100
#  - 40s - loss: 4.7112e-04
# Epoch 11/100
#  - 43s - loss: 4.7859e-04
# Epoch 12/100
# ...

# %%
from spreadsheetfunctions import *

# %% [markdown]
# model.save('RNN-erotonehundred.h5')

# %%
model= load_model('RNN-erotonehundred.h5')

# %%
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)

# %%
joineddf.columns
# Out:
# Index(['Settlement Point Price'], dtype='object')

# %%
#for plotting
# %matplotlib inline
train = joineddf[:split]
valid = joineddf[split:]
valid['Predictions'] = closing_price
plt.figure(figsize=(18,9))
plt.plot(train['Settlement Point Price'])
plt.plot(valid['Settlement Point Price'], label = 'Prophet yhat Expected Price')
plt.plot(valid['Predictions'], label = 'Predicted ERCOT North HUB Realtime Price from RNN')
plt.legend()
plt.title('ERCOT North Hub forecast using Prophet and LSTM RNN')
plt.show();

# %%
valid
# Out:
#                      Settlement Point Price  Predictions
# Formatted_DATE
# 2019-04-16 08:00:00               19.500000    19.318676
# 2019-04-16 09:00:00               18.260000    17.507561
# 2019-04-16 10:00:00               20.740000    15.931908
# 2019-04-16 11:00:00               20.570000    19.333134
# 2019-04-16 12:00:00               20.490000    18.460579
# 2019-04-16 13:00:00               20.170000    18.510689
# 2019-04-16 14:00:00               22.000000    18.235582
# 2019-04-16 15:00:00               22.520000    20.558260
# 2019-04-16 16:00:00               26.680000    20.795048
# 2019-04-16 17:00:00               24.400000    25.719761
# 2019-04-16 18:00:00               23.000000    22.183701
# 2019-04-16 19:00:00               21.630000    21.699301
# 2019-04-16 20:00:00               19.710000    20.575521
# 2019-04-16 21:00:00               19.500000    18.483646
# 2019-04-16 22:00:00               18.210000    18.348665
# ...

# %%
rms=np.sqrt(np.mean(np.power((valid['Settlement Point Price']- valid['Predictions']),2)))
rms
# Out:
# 4.337499179327651
